# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepaTS/386.5_MatPlotLib/blob/main/GLAB_386_5_7_Matplotlib_Pyplot_Control_the_Properties_of_the_Figure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Guided Lab - 386.5.7 - Matplotlib Pyplot: Control the Properties of the Figure**
#
#
# ---

# %% [markdown]
# ##**Lab objective:**
#
# In this lab, we will demonstrate how to control the properties of the figure by using `plt.figure()`.

# %% [markdown]
# ##**Introduction:**
# **plt.figure()** allows you to explicitly control the properties of the figure before plotting anything on it. We can also specify various parameters when calling plt.figure() to customize the figure such as its size, aspect ratio, and background color.

# %% [markdown]
# In this example, we will creates a new figure object using **plt.figure()**, which is then used to plot some data. If you do not call plt.figure(), Matplotlib will automatically create a new figure when you first plot something. However, using plt.figure() allows you to explicitly control the properties of the figure before plotting anything on it.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 170, 190, 160, 300, 310, 320, 330])

# Create a new figure with default parameters
fig = plt.figure()

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

# Plot with specified marker, linestyle, and color
plt.plot(x, y, marker='D', linestyle='dotted', color="blue")

# Enabling X-axis grid lines:
plt.grid(color="red")
plt.savefig("gfgfg")

# %% [markdown]
# You can also specify various parameters when calling **plt.figure()** to customize the figure such as the figure size, aspect ratio, background color, etc. For example:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 170, 190, 160, 300, 310, 320, 330])

#creates a new figure with a custom size of 9x10 inches.
fig = plt.figure(figsize=(9, 10))

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

# Plot with specified marker, linestyle, and color
plt.plot(x, y, marker='D', linestyle='dotted', color="blue")

# Enabling X-axis grid lines:
plt.grid(color="red",alpha=0.2)
fig.set_facecolor("lightgray")
plt.show()

# %% [markdown]
# The **dpi** can be passed as an argument to the figure() function. We can control the width of objects (axes, fonts, lines, markers) in the figure. Below are two figures, both having the **same pixel size**: 432x432 but different dpi and figsize values:
#
# 6x6 * 72 dpi = 432x432 pixel size
#
# 3x3 * 144 dpi = 432x432 pixel size

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 170, 190, 160, 300, 310, 320, 330])

#creates a new figure with a custom size of 9x10 inches.
plt.figure(figsize=(6, 6), dpi=72)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

# Plot with specified marker, linestyle, and color
plt.plot(x, y, marker='D', linestyle='dotted', color="blue")

# Enabling X-axis grid lines:
plt.grid(color="red")

plt.show()

# %% [markdown]
# You can increaze the size of dpi, such as dpi=144

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 170, 190, 160, 300, 310, 320, 330])

#creates a new figure with a custom size of 9x10 inches.
plt.figure(figsize=(3, 3), dpi=144)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

# Plot with specified marker, linestyle, and color
plt.plot(x, y, marker='D', linestyle='dotted', color="blue")

# Enabling X-axis grid lines:
plt.grid(color="red")

plt.show()

# %% [markdown]
# As you can see in the above images, the figure with a larger dpi has wider lines, axes, a larger font, and fewer tick labels - dpi magnifies all elements. You can read an amazing explanation of the relationship between dpi and figsize in this [StackOverflow response](https://stackoverflow.com/questions/47633546/relationship-between-dpi-and-figure-size/47639545#47639545).
