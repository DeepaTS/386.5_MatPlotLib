# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepaTS/386.5_MatPlotLib/blob/main/GLAB_386_5_3_Matplotlib_Pyplot_Define_Custom_Color.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Guided LAB - 386.5.3 - Matplotlib Pyplot - Define Custom Color**

# %% [markdown]
# ##**Learning Objective:**
#
# This lab demonstrates various ways to customize colors in your Matplotlib plot. Experiment with different options to create visually appealing and informative plots!
#
# By the end of this lab, learners will be able to specify colors for plot elements such as labels, titles, and lines.

# %% [markdown]
# ##**Define Custom Colors**

# %% [markdown]
# Matplotlib allows you to specify colors using various formats such as RGB tuples, hex strings, or predefined color names.
#
# Below is the basic Syntax:

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 170, 190, 160, 300, 310, 320, 330])

# Using predefined color names
plt.plot(x, y, color='blue')

# Using RGB tuples
plt.plot(x, y, color=(0.1, 0.2, 0.5))

# Using hex strings color code
plt.plot(x, y, color='#FF5733')

# %% [markdown]
# ###**Example 1.1: Using predefined color names**

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 170, 190, 160, 300, 310, 320, 330])
# Set plot colors and market
plt.plot(x, y, marker = 'D', linestyle='dotted', color="blue")
plt.title("Title: Sports Watch Data")
plt.xlabel("Label: Average Pulse" )
plt.ylabel("Label: Calorie Burnage")
plt.show()

# %% [markdown]
# ###**Example 1.2: Using RGB tuples**

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 170, 190, 160, 300, 310, 320, 330])
# Set plot colors
plt.plot(x, y, marker = 'D', linestyle='dotted',  color=(0.5, 0.2, 0.5))
plt.title("Title: Sports Watch Data")
plt.xlabel("Label: Average Pulse" )
plt.ylabel("Label: Calorie Burnage")
plt.show()

# %% [markdown]
# ###**Example 1.3: Using hex strings color code**

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 170, 190, 160, 300, 310, 320, 330])

# Set plot colors
plt.plot(x, y, marker = 'D', linestyle='dotted', color="#FF6738")
plt.title("Title: Sports Watch Data")
plt.xlabel("Label: Average Pulse" )
plt.ylabel("Label: Calorie Burnage")
plt.show()

# %% [markdown]
# ## **Example 1.4: Changing Title and labels color**

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 170, 190, 160, 300, 310, 320, 330])

# Set plot colors
plt.plot(x, y, marker = 'D', linestyle='dotted', color="#FF5733",markerfacecolor='yellow')
plt.title("Title: Sports Watch Data", color="Blue")
plt.xlabel("Label: Average Pulse", color ="green" )
plt.ylabel("Label: Calorie Burnage", color="red")
plt.show()

# %% [markdown]
# ##**Example 1.5: World population graph**
#
# Let's see one more example:

# %%
import matplotlib.pyplot as plt
years=[1970,1980,1985,1990,1995,2000,2005,2010,2015,2020,2025,2030,2035]
pops=[3.6,4.0,4.4,4.8,5.3,5.7,6.1,6.5,7.3,7.3,7.3,7.4,7.5]


plt.title("Title: World population graph", color="Blue")
plt.xlabel("Population growth by year", color ="green" )
plt.ylabel("Population in Billions", color="red")

plt.plot(years,pops)
plt.show()

# %% [markdown]
# Reference: https://matplotlib.org/stable/users/explain/colors/index.html
